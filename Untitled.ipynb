# %% [markdown]
# It ends with us

# %%
Today will be a good day
# Out:
#   File "<ipython-input-1-60dec6339be4>", line 1
#     Today will be a good day
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Today will be a good day

# %% [raw]
# Today will be a good day

# %% [markdown]
# Netflix Revamps Its Logo | DesignMantic: The Design Shop

# %% [markdown]
# # Housing Price Prediction Project

# %% [markdown]
# ![technology-article-1080x608-1.webp](attachment:technology-article-1080x608-1.webp)

# %% [markdown]
# # Hello

# %% [markdown]
# ## Hello

# %% [markdown]
# ### Hello

# %% [markdown]
# #### Hello

# %% [markdown]
# <a href="your_url_here">Showing Text</a>

# %% [markdown]
# <a href="http://www.netflix.com/browse/genre/">Netflix login</a>

# %% [markdown]
#  - Red

# %% [markdown]
# - Red

# %% [markdown]
# <font color=blue>Blue</font>

# %% [markdown]
# > Idented quoting

# %% [markdown]
# ![A9DF1171_458C_4D7B_A253_573AF2ED7CB6.png](attachment:A9DF1171_458C_4D7B_A253_573AF2ED7CB6.png)

# %% [markdown]
# > PROJECT ROUGH WORK DRAFT

# %% [markdown]
# # DESCRIBING THE QUESTION

# %% [markdown]
# ## 1. BUSINESS UNDERSTANDING

# %% [markdown]
# My task as a Data Scientist is to process data from some of the big companies that create original video content. This will be done by exploring the types of films are currently doing the best at the box office and translating those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.

# %% [markdown]
#  - Business Objectives

# %%
#Actionable insight that would help microsoft in decision making on what type of film to produce to yield the most profit

# %% [markdown]
#  - Assess situation

# %% [markdown]
#  - Determine data mining goals

# %%
#The metric of success is rating and sales made from the movie

# %% [markdown]
#  - Produce project plan

# %% [markdown]
# ## 2. DATA UNDERSTANDING

# %%
#collect, describe,explore, verify data quality-data cleaning

# %% [markdown]
# ## 3. DATA PREPARATION

# %% [markdown]
# ## 4. CONCLUSION

# %% [markdown]
# ## 5. RECOMMENDATIONS

# %% [markdown]
# MOVIE PROFITABILITY PREDICTION PROJECT
# download.jpg
#
# DESCRIBING THE QUESTION
# 1. BUSINESS UNDERSTANDING
# My task as a Data Scientist is to process data from some of the big companies that create original video content. This will be done by exploring the types of films are currently doing the best at the box office and translating those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.
#
# Business Objective: To find the most profitable film to create
# Assess situation: Data to be assesed is IMDB
# Metric of success: worldwide gross
# 2. DATA UNDERSTANDING
# The data was collected from IMDB Website
#
# 3. DATA PREPARATION
# ​
# 4. CONCLUSION
# ​
# 5. RECOMMENDATIONS¶
